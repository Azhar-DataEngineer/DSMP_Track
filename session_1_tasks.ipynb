# %% [markdown]
# <a href="https://colab.research.google.com/github/Azhar-DataEngineer/DSMP_Track/blob/main/session_1_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
print("Data", "Science", "Mentorship", "Program", sep="-", end="-started-")
print("By", "CampusX", sep="-")
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
celsius = float(input("Enter the temparature in Celsius"))

fahrenheit = (celsius * 9/5) + 32

print(f"Temparature in Fahrenheit is {fahrenheit}")
# Out:
# Enter the temparature in Celsius32
# Temparature in Fahrenheit is 89.6

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
num1 = int(input("Enter the number 1"))
num2 = int(input("Enter the number 2"))

num3 = None

num3 = num1
num1 = num2
num2 = num3

print(f"Number2 = {num2}")
print(f"Number1 = {num1}")
# Out:
# Enter the number 110
# Enter the number 220
# Number2 = 10
# Number1 = 20

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Input coordinates for point 1
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))

# Input coordinates for point 2
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

# Calculate Euclidean distance
distance = ((x2 - x1)**2 + (y2 - y1)**2)**0.5

print(f"The Euclidean distance between ({x1}, {y1}) and ({x2}, {y2}) is {distance:.4f}")
# Out:
# Enter x1: 2
# Enter y1: 3
# Enter x2: 4
# Enter y2: 5
# The Euclidean distance between (2.0, 3.0) and (4.0, 5.0) is 2.8284

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
principle = float(input("Enter the principle amount"))
rate = float(input("Enter the rate of interest"))
time = float(input("Enter the time period"))

simple_interest = (principle * rate * time)/100

print(f"The simple interest is {simple_interest}")
# Out:
# Enter the principle amount100000
# Enter the rate of interest10
# Enter the time period2
# The simple interest is 20000.0

# %% [markdown]
# \### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
heads = int(input("Enter the number of heads"))
legs = int(input("Enter the number of legs"))

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
number = int(input("Enter the number"))
sum = 0

for num in range(1,number+1):
  sum = sum + (num * num)

print(sum)
# Out:
# Enter the number5
# 55

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# an = a + (n-1)*d


first_num = int(input("Enter the first number in the series"))

second_num = int(input("Enter the second number in the series"))

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
